# %%
import numpy as np
from scipy import io
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from scipy import io

# %%
expt1=io.loadmat('expt1/output.mat')
loss=expt1['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2e6);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 93916.059938    93312.27649709  93732.80817917  93615.6972037
#   93636.22336396]

# %%
expt2=io.loadmat('expt2/output.mat')
loss=expt2['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2000);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 357.95672778  360.69972242  365.01040257  369.05746308  369.9693366 ]

# %%
plt.plot(expt2['Y']);

# %%
plt.plot(expt2['Xhat']);

# %%
plt.plot(expt2['Y'].ravel(),expt2['Xhat'].ravel(),'.');
plt.plot([0, 20000],[0, 20000],'k');

# %%
expt3=io.loadmat('expt3/output.mat')
loss=expt3['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2000);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 416.85486543  360.4036306   397.98036547  367.75007378  410.37125275]

# %%
plt.plot(expt3['Y'].ravel(),expt3['Xhat'].ravel(),'.');
plt.plot((0,expt3['Y'].max()*1.05),(0,expt3['Xhat'].max()*1.05),'k--');
plt.plot([0, 20000],[0, 20000],'k');

# %%
expt5=io.loadmat('expt5/output.mat')
loss=expt5['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2000);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 494.07537999  551.27461902  473.18558515  452.97478679  470.1517871 ]

# %%
plt.plot(expt5['Y'].ravel(),expt5['Xhat'].ravel(),'.');
plt.plot((0,expt5['Y'].max()*1.05),(0,expt5['Xhat'].max()*1.05),'k--');
plt.plot([0, 20000],[0, 20000],'k');

# %%
expt4=io.loadmat('expt4/output.mat')
loss=expt4['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2000);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 630.72354175  666.66507633  622.30535816  694.76639042  576.23221605]

# %%
plt.plot(expt4['Y'].ravel(),expt4['Xhat'].ravel(),'.');
plt.plot((0,expt4['Y'].max()*1.05),(0,expt4['Xhat'].max()*1.05),'k--');
plt.plot([0, 20000],[0, 20000],'k');

# %%
recon = expt2['recon'];
print np.max(recon)
recon = np.reshape(recon, IM.shape)
plt.imshow(recon)  #,  vmin=Cmin, vmax=Cmax)
plt.show()

recon_gt = expt2['recon_gt'];
print recon_gt.shape
recon_gt = np.reshape(recon_gt, IM.shape)

Cmin = 0
Cmax = np.max(recon_gt)
print 'Color limits:', (Cmin, Cmax)
plt.imshow(recon_gt, vmin=Cmin, vmax=Cmax)
plt.show()

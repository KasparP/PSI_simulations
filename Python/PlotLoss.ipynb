# %%
import numpy as np
from scipy import io
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from scipy import io

# %%
expt1=io.loadmat('expt1/output.mat')
loss=expt1['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2e6);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 93916.059938    93312.27649709  93732.80817917  93615.6972037
#   93636.22336396]

# %%
expt2=io.loadmat('expt2/output.mat')
loss=expt2['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2000);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 536.12568137  537.71262363  526.50378447  524.56231524  519.6149673 ]

# %%
plt.plot(expt2['Y']);

# %%
plt.plot(expt2['Xhat']);

# %%
plt.plot(expt2['Y'].ravel(),expt2['Xhat'].ravel(),'.');
plt.plot([0, 20000],[0, 20000],'k');

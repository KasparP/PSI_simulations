# %%
import numpy as np
from scipy import io
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from scipy import io

# %% [markdown]
# ## Experiment 1
# Description of experiment

# %%
expt1=io.loadmat('expt1/output.mat')
loss=expt1['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,3e6);
plt.xlabel('iteration');
plt.ylabel('MSE');

# %%
expt1=io.loadmat('expt1/output.mat')
loss_gt = expt1['loss_gt']
loss_gt = loss_gt[loss_gt>0]
loss_gtall = loss_gt[::100]
tall = np.arange(len(loss_gtall))*100

print 'Last 5 full loss iterations vs ground truth'
print loss_gtall[-5:]

plt.plot(loss_gt,'.');
plt.plot(tall,loss_gtall,'ko-');
plt.legend(('Subsampled loss','Full loss GT'));
plt.ylim(0,2*np.amax(loss_gtall));
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations vs ground truth
# [ 183515.0905036]

# %%
expt1=io.loadmat('output.mat')
loss=expt1['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,3e6);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 1821642.83447686]

# %% [markdown]
# ## -- Experiment 2 --
# Description of experiment

# %%
expt2=io.loadmat('expt2/output.mat')
loss=expt2['loss']
loss = loss[loss>0]
lossall = loss[::100]
tall = np.arange(len(lossall))*100

print 'Last 5 full loss iterations'
print lossall[-5:]

plt.plot(loss,'.');
plt.plot(tall,lossall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,3e6);
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 1110508.35858785  1100896.41842176  1094164.40311622  1056116.94751495
#    942223.4014652 ]

# %%
expt2=io.loadmat('expt2/output.mat')
loss_gt=expt2['loss_gt']
loss_gt = loss_gt[loss_gt>0]
lossgtall = loss_gt[::100]
tall = np.arange(len(lossgtall))*100

print 'Last 5 full loss iterations'
print lossgtall[-5:]

plt.plot(loss_gt,'.');
plt.plot(tall,lossgtall,'ko-');
plt.legend(('Subsampled loss','Full loss'));
plt.ylim(0,2*np.amax(loss_gtall));
plt.xlabel('iteration');
plt.ylabel('MSE');
# Out:
# Last 5 full loss iterations
# [ 114836.80530928  114845.9144335   114853.08285477  114826.92757088
#   114712.14306754]

# %%
#REFERENCE IMAGE
IM = expt2['IM']
plt.imshow(IM)
plt.show()

# %%
#GROUND TRUTH
recon_gt = expt2['recon_gt'];
recon_gt = np.reshape(recon_gt[:,0], IM.shape)
plt.imshow(recon_gt)
plt.show()

# %%
#RECONSTRUCTION
recon = expt2['recon'];
recon = np.reshape(recon[:,0], IM.shape)
plt.imshow(recon)
plt.show()

# %%
plt.plot(expt2['Xhat']);

# %%
plt.plot(expt2['Y']);

# %%
plt.plot(expt2['Y'].ravel(),expt2['Xhat'].ravel(),'.');
plt.plot([0, 20000],[0, 20000],'k');
